# %% [markdown]
# !pip install selenium
#
# !pip install beautifulsoup

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time
import pandas as pd

# %% [markdown]
# ## Definindo a url

# %%
job_name = "data scientist"
country_name = "Brasil"

job_url ="";
for item in job_name.split(" "):
    if item != job_name.split(" ")[-1]:
        job_url = job_url + item + "%20"
    else:
        job_url = job_url + item

country_url ="";
for item in country_name.split(" "):
    if item != country_name.split(" ")[-1]:
        country_url = country_url + item + "%20"
    else:
        country_url = country_url + item

url = "https://www.linkedin.com/jobs/search?keywords={0}&location={1}&geoId=106057199&trk=public_jobs_jobs-search-bar_search-submit&position=1&pageNum=0"
# Out:
# 'https://www.linkedin.com/jobs/search?keywords=data%20scientist&location=Brasil&geoId=106057199&trk=public_jobs_jobs-search-bar_search-submit&position=1&pageNum=0'

# %%
## iniciando o Mozilla

# %%
driver = webdriver.Firefox()

driver.get(url.format(job_url,country_url))

# %%
jobs_num = driver.find_element(By.CSS_SELECTOR,"h1>span").get_attribute("innerText")
if len(jobs_num.split('.')) > 1:
    jobs_num = int(jobs_num.split('.')[0])*1000
else:
    jobs_num = int(jobs_num)

jobs_num   = int(jobs_num)

#We create a while loop to browse all jobs. 
i = 2
while i <= int(jobs_num/2)+1:
    #We keep scrollind down to the end of the view.
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    i = i + 1
    print("Current at: ", i, "Percentage at: ", ((i+1)/(int(jobs_num/2)+1))*100, "%",end="\r")
    try:
        #We try to click on the load more results buttons in case it is already displayed.
        infinite_scroller_button = driver.find_element(By.XPATH, ".//button[@aria-label='Ver mais vagas']")
        infinite_scroller_button.click()
        time.sleep(0.1)
    except:
        #If there is no button, there will be an error, so we keep scrolling down.
        time.sleep(0.1)
        pass

# %%
job_lists = driver.find_element(By.CLASS_NAME,"jobs-search__results-list")
jobs = job_lists.find_elements(By.TAG_NAME,"li") # return a list

#We declare void list to keep track of all obtaind data.
job_title_list = []
company_name_list = []
location_list = []
date_list = []
job_link_list = []

#We loof over every job and obtain all the wanted info.
for job in jobs:
    #job_title
    job_title = job.find_element(By.CSS_SELECTOR,"h3").get_attribute("innerText")
    job_title_list.append(job_title)
    
    #company_name
    company_name = job.find_element(By.CSS_SELECTOR,"h4").get_attribute("innerText")
    company_name_list.append(company_name)
    
    #location
    location = job.find_element(By.CSS_SELECTOR,"div>div>span").get_attribute("innerText")
    location_list.append(location)
    
    #date
    date = job.find_element(By.CSS_SELECTOR,"div>div>time").get_attribute("datetime")
    date_list.append(date)
    
    #job_link
    job_link = job.find_element(By.CSS_SELECTOR,"a").get_attribute("href")
    job_link_list.append(job_link)

# %%
jd = [] #job_description
seniority = []
emp_type = []
job_func = []
job_ind = []
for item in range(len(jobs)):
    print(item)
    job_func0=[]
    industries0=[]
    # clicking job to view job details
    
    #__________________________________________________________________________ JOB Link
    
    try: 
        job_click_path = f'/html/body/div/div/main/section/ul/li[{item+1}]'
        job_click = job.find_element(By.XPATH,job_click_path).click()
    except:
        pass
    #job_click = job.find_element(By.XPATH,'.//a[@class="base-card_full-link"]')
    
    #__________________________________________________________________________ JOB Description
    jd_path = '/html/body/div/div/section/div/div/section/div/div/section/div'
    try:
        jd0 = job.find_element(By.XPATH,jd_path).get_attribute('innerText')
        jd.append(jd0)
    except:
        jd.append(None)
        pass
    
    #__________________________________________________________________________ JOB Seniority
    seniority_path='/html/body/div/div/section/div/div/section/div/ul/li[1]/span'
    
    try:
        seniority0 = job.find_element(By.XPATH,seniority_path).get_attribute('innerText')
        seniority.append(seniority0)
    except:
        seniority.append(None)
        pass

    #__________________________________________________________________________ JOB Time
    emp_type_path='/html/body/div/div/section/div/div/section/div/ul/li[2]/span'
    
    try:
        emp_type0 = job.find_element(By.XPATH,emp_type_path).get_attribute('innerText')
        emp_type.append(emp_type0)
    except:
        emp_type.append(None)
        pass
    
    #__________________________________________________________________________ JOB Function
    function_path='/html/body/div/div/section/div/div/section/div/ul/li[3]/span'
    
    try:
        func0 = job.find_element(By.XPATH,function_path).get_attribute('innerText')
        job_func.append(func0)
    except:
        job_func.append(None)
        pass

    #__________________________________________________________________________ JOB Industry
    industry_path='/html/body/div/div/section/div/div/section/div/ul/li[4]/span'
    
    try:
        ind0 = job.find_element(By.XPATH,industry_path).get_attribute('innerText')
        job_ind.append(ind0)
    except:
        job_ind.append(None)
        pass
    
    print("Current at: ", item, "Percentage at: ", (item+1)/len(jobs)*100, "%")
# Out:
# 0
# Current at:  0 Percentage at:  4.0 %
# 1
# Current at:  1 Percentage at:  8.0 %
# 2
# Current at:  2 Percentage at:  12.0 %
# 3
# Current at:  3 Percentage at:  16.0 %
# 4
# Current at:  4 Percentage at:  20.0 %
# 5
# Current at:  5 Percentage at:  24.0 %
# 6
# Current at:  6 Percentage at:  28.000000000000004 %
# 7
# Current at:  7 Percentage at:  32.0 %
# 8
# Current at:  8 Percentage at:  36.0 %
# 9
# Current at:  9 Percentage at:  40.0 %
# 10
# Current at:  10 Percentage at:  44.0 %
# 11
# Current at:  11 Percentage at:  48.0 %
# 12
# Current at:  12 Percentage at:  52.0 %
# 13
# Current at:  13 Percentage at:  56.00000000000001 %
# 14
# Current at:  14 Percentage at:  60.0 %
# 15
# Current at:  15 Percentage at:  64.0 %
# 16
# Current at:  16 Percentage at:  68.0 %
# 17
# Current at:  17 Percentage at:  72.0 %
# 18
# Current at:  18 Percentage at:  76.0 %
# 19
# Current at:  19 Percentage at:  80.0 %
# 20
# Current at:  20 Percentage at:  84.0 %
# 21
# Current at:  21 Percentage at:  88.0 %
# 22
# Current at:  22 Percentage at:  92.0 %
# 23
# Current at:  23 Percentage at:  96.0 %
# 24
# Current at:  24 Percentage at:  100.0 %

# %%
job_data = pd.DataFrame({
    'Date': date,
    'Company': company_name,
    'Title': job_title,
    'Location': location,
    'Description': jd,
    'Level': seniority,
    'Type': emp_type,
    'Function': job_func,
    'Industry': job_ind,
    'Link': job_link
})

# %%
job_data.head(30)
# Out:
#           Date Company                  Title       Location  \
# 0   2023-04-29   Porto  CIENTISTA DE DADOS PL  São Paulo, SP
# 1   2023-04-29   Porto  CIENTISTA DE DADOS PL  São Paulo, SP
# 2   2023-04-29   Porto  CIENTISTA DE DADOS PL  São Paulo, SP
# 3   2023-04-29   Porto  CIENTISTA DE DADOS PL  São Paulo, SP
# 4   2023-04-29   Porto  CIENTISTA DE DADOS PL  São Paulo, SP
# 5   2023-04-29   Porto  CIENTISTA DE DADOS PL  São Paulo, SP
# 6   2023-04-29   Porto  CIENTISTA DE DADOS PL  São Paulo, SP
# 7   2023-04-29   Porto  CIENTISTA DE DADOS PL  São Paulo, SP
# 8   2023-04-29   Porto  CIENTISTA DE DADOS PL  São Paulo, SP
# 9   2023-04-29   Porto  CIENTISTA DE DADOS PL  São Paulo, SP
# 10  2023-04-29   Porto  CIENTISTA DE DADOS PL  São Paulo, SP
# 11  2023-04-29   Porto  CIENTISTA DE DADOS PL  São Paulo, SP
# 12  2023-04-29   Porto  CIENTISTA DE DADOS PL  São Paulo, SP
# 13  2023-04-29   Porto  CIENTISTA DE DADOS PL  São Paulo, SP
# 14  2023-04-29   Porto  CIENTISTA DE DADOS PL  São Paulo, SP
# 15  2023-04-29   Porto  CIENTISTA DE DADOS PL  São Paulo, SP
# 16  2023-04-29   Porto  CIENTISTA DE DADOS PL  São Paulo, SP
# 17  2023-04-29   Porto  CIENTISTA DE DADOS PL  São Paulo, SP
# 18  2023-04-29   Porto  CIENTISTA DE DADOS PL  São Paulo, SP
# 19  2023-04-29   Porto  CIENTISTA DE DADOS PL  São Paulo, SP
# 20  2023-04-29   Porto  CIENTISTA DE DADOS PL  São Paulo, SP
# 21  2023-04-29   Porto  CIENTISTA DE DADOS PL  São Paulo, SP
# 22  2023-04-29   Porto  CIENTISTA DE DADOS PL  São Paulo, SP
# 23  2023-04-29   Porto  CIENTISTA DE DADOS PL  São Paulo, SP
# 24  2023-04-29   Porto  CIENTISTA DE DADOS PL  São Paulo, SP
#
#                                           Description  \
# 0   Estamos com processo seletivo para a cidade de...
# 1   \n        Estamos com processo seletivo para a...
# 2   Já imaginou ser um Porto Seguro para mais de 1...
# 3   OBJETIVO DO CARGO\n\nIrá atuar na célula de Da...
# 4   No AC Camargo Cancer Center ser Cientista de D...
# 5   Como Cientista de Dados na Montreal, você fará...
# 6   \n        Como Cientista de Dados na Montreal,...
# 7   \n        Como Cientista de Dados na Montreal,...
# 8   \n        Como Cientista de Dados na Montreal,...
# 9   \n        Como Cientista de Dados na Montreal,...
# 10  \n        Como Cientista de Dados na Montreal,...
# 11  #LI- REMOTE\n\n\n\n\nQuem é Stone Tech?\n\n\n\...
# 12  \n        #LI- REMOTEQuem é Stone Tech? A Ston...
# 13  \n        #LI- REMOTEQuem é Stone Tech? A Ston...
# 14  \n        #LI- REMOTEQuem é Stone Tech? A Ston...
# 15  \n        #LI- REMOTEQuem é Stone Tech? A Ston...
# 16  \n        #LI- REMOTEQuem é Stone Tech? A Ston...
# 17  Creditas é uma plataforma digital focada em me...
# 18  \n        Creditas é uma plataforma digital fo...
# 19  \n        Creditas é uma plataforma digital fo...
# 20  \n        Creditas é uma plataforma digital fo...
# 21  \n        Creditas é uma plataforma digital fo...
# 22  \n        Creditas é uma plataforma digital fo...
# 23  \n        Creditas é uma plataforma digital fo...
# 24  \n        Creditas é uma plataforma digital fo...
#
#                                       Level  \
# 0                             Não aplicável
# 1   \n            Não aplicável\n
# 2                              Pleno-sênior
# 3                             Não aplicável
# 4                                Assistente
# 5                             Não aplicável
# 6   \n            Não aplicável\n
# 7   \n            Não aplicável\n
# 8   \n            Não aplicável\n
# 9   \n            Não aplicável\n
# 10  \n            Não aplicável\n
# 11                             Pleno-sênior
# 12   \n            Pleno-sênior\n
# 13   \n            Pleno-sênior\n
# 14   \n            Pleno-sênior\n
# 15   \n            Pleno-sênior\n
# 16   \n            Pleno-sênior\n
# 17                             Pleno-sênior
# 18   \n            Pleno-sênior\n
# 19   \n            Pleno-sênior\n
# 20   \n            Pleno-sênior\n
# 21   \n            Pleno-sênior\n
# 22   \n            Pleno-sênior\n
# 23   \n            Pleno-sênior\n
# 24   \n            Pleno-sênior\n
#
#                                     Type  \
# 0                         Tempo integral
# 1   \n          Tempo integral\n
# 2                         Tempo integral
# 3                         Tempo integral
# 4                         Tempo integral
# 5                         Tempo integral
# 6   \n          Tempo integral\n
# 7   \n          Tempo integral\n
# 8   \n          Tempo integral\n
# 9   \n          Tempo integral\n
# 10  \n          Tempo integral\n
# 11                        Tempo integral
# 12  \n          Tempo integral\n
# 13  \n          Tempo integral\n
# 14  \n          Tempo integral\n
# 15  \n          Tempo integral\n
# 16  \n          Tempo integral\n
# 17                        Tempo integral
# 18  \n          Tempo integral\n
# 19  \n          Tempo integral\n
# 20  \n          Tempo integral\n
# 21  \n          Tempo integral\n
# 22  \n          Tempo integral\n
# 23  \n          Tempo integral\n
# 24  \n          Tempo integral\n
#
#                                              Function  \
# 0                                               Outro
# 1                     \n            Outro\n
# 2   Desenvolvimento de negócios e Estratégia/Plane...
# 3               Engenharia e Tecnologia da informação
# 4               Engenharia e Tecnologia da informação
# 5               Engenharia e Tecnologia da informação
# 6   \n            Engenharia e Tecnologia da infor...
# 7   \n            Engenharia e Tecnologia da infor...
# 8   \n            Engenharia e Tecnologia da infor...
# 9   \n            Engenharia e Tecnologia da infor...
# 10  \n            Engenharia e Tecnologia da infor...
# 11              Engenharia e Tecnologia da informação
# 12  \n            Engenharia e Tecnologia da infor...
# 13  \n            Engenharia e Tecnologia da infor...
# 14  \n            Engenharia e Tecnologia da infor...
# 15  \n            Engenharia e Tecnologia da infor...
# 16  \n            Engenharia e Tecnologia da infor...
# 17              Engenharia e Tecnologia da informação
# 18  \n            Engenharia e Tecnologia da infor...
# 19  \n            Engenharia e Tecnologia da infor...
# 20  \n            Engenharia e Tecnologia da infor...
# 21  \n            Engenharia e Tecnologia da infor...
# 22  \n            Engenharia e Tecnologia da infor...
# 23  \n            Engenharia e Tecnologia da infor...
# 24  \n            Engenharia e Tecnologia da infor...
#
#                                              Industry  \
# 0              Programas de administração educacional
# 1   \n          Programas de administração educaci...
# 2                      Seguros e Serviços financeiros
# 3                           Atendimento ao consumidor
# 4                     Hospitais e atendimento à saúde
# 5                        Serviços e consultoria de TI
# 6   \n          Serviços e consultoria de TI\n    ...
# 7   \n          Serviços e consultoria de TI\n    ...
# 8   \n          Serviços e consultoria de TI\n    ...
# 9   \n          Serviços e consultoria de TI\n    ...
# 10  \n          Serviços e consultoria de TI\n    ...
# 11                       Serviços e consultoria de TI
# 12  \n          Serviços e consultoria de TI\n    ...
# 13  \n          Serviços e consultoria de TI\n    ...
# 14  \n          Serviços e consultoria de TI\n    ...
# 15  \n          Serviços e consultoria de TI\n    ...
# 16  \n          Serviços e consultoria de TI\n    ...
# 17                               Serviços financeiros
# 18       \n          Serviços financeiros\n
# 19       \n          Serviços financeiros\n
# 20       \n          Serviços financeiros\n
# 21       \n          Serviços financeiros\n
# 22       \n          Serviços financeiros\n
# 23       \n          Serviços financeiros\n
# 24       \n          Serviços financeiros\n
#
#                                                  Link
# 0   https://br.linkedin.com/jobs/view/cientista-de...
# 1   https://br.linkedin.com/jobs/view/cientista-de...
# 2   https://br.linkedin.com/jobs/view/cientista-de...
# 3   https://br.linkedin.com/jobs/view/cientista-de...
# 4   https://br.linkedin.com/jobs/view/cientista-de...
# 5   https://br.linkedin.com/jobs/view/cientista-de...
# 6   https://br.linkedin.com/jobs/view/cientista-de...
# 7   https://br.linkedin.com/jobs/view/cientista-de...
# 8   https://br.linkedin.com/jobs/view/cientista-de...
# 9   https://br.linkedin.com/jobs/view/cientista-de...
# 10  https://br.linkedin.com/jobs/view/cientista-de...
# 11  https://br.linkedin.com/jobs/view/cientista-de...
# 12  https://br.linkedin.com/jobs/view/cientista-de...
# 13  https://br.linkedin.com/jobs/view/cientista-de...
# 14  https://br.linkedin.com/jobs/view/cientista-de...
# 15  https://br.linkedin.com/jobs/view/cientista-de...
# 16  https://br.linkedin.com/jobs/view/cientista-de...
# 17  https://br.linkedin.com/jobs/view/cientista-de...
# 18  https://br.linkedin.com/jobs/view/cientista-de...
# 19  https://br.linkedin.com/jobs/view/cientista-de...
# 20  https://br.linkedin.com/jobs/view/cientista-de...
# 21  https://br.linkedin.com/jobs/view/cientista-de...
# 22  https://br.linkedin.com/jobs/view/cientista-de...
# 23  https://br.linkedin.com/jobs/view/cientista-de...
# 24  https://br.linkedin.com/jobs/view/cientista-de...

# %%
job_data.to_csv("data/vagas.csv")
