# %%
import pandas as pd
import numpy as np

# %%
dfNba = pd.read_csv("data/nba_stats.csv")

# %%
pd.set_option('display.max_columns', None)

# %%
dfNba.head()
# Out:
#    year           name  playerId     playerSlug positionId teamId    status  \
# 0  1999  Allen Iverson       366  allen-iverson         SG    PHI  inactive
# 1  2000  Allen Iverson       366  allen-iverson         SG    PHI  inactive
# 2  2001  Allen Iverson       366  allen-iverson         SG    PHI  inactive
# 3  2002  Allen Iverson       366  allen-iverson         SG    PHI  inactive
# 4  2003  Allen Iverson       366  allen-iverson         SG    PHI  inactive
#
#    gamesPlayed  avgMinutes  avgFouls  flagrantFouls  technicalFouls  \
# 0         48.0   41.458332  2.041667            0.0             5.0
# 1         70.0   40.757140  2.314286            0.0            12.0
# 2         71.0   41.957745  2.070423            0.0            18.0
# 3         60.0   43.700000  1.700000            0.0            12.0
# 4         82.0   42.500000  1.817073            0.0             8.0
#
#    ejections  doubleDouble  tripleDouble  minutes  rebounds  fouls  \
# ...

# %%
dfLimpo = dfNba.copy()

# %%
dfLimpo['salary'] = dfLimpo['salary'].astype(str).str.replace(r'\$|,', '', regex = True).astype(np.float64)

# %%
dfLimpo.head()
# Out:
#    year           name  playerId     playerSlug positionId teamId    status  \
# 0  1999  Allen Iverson       366  allen-iverson         SG    PHI  inactive
# 1  2000  Allen Iverson       366  allen-iverson         SG    PHI  inactive
# 2  2001  Allen Iverson       366  allen-iverson         SG    PHI  inactive
# 3  2002  Allen Iverson       366  allen-iverson         SG    PHI  inactive
# 4  2003  Allen Iverson       366  allen-iverson         SG    PHI  inactive
#
#    gamesPlayed  avgMinutes  avgFouls  flagrantFouls  technicalFouls  \
# 0         48.0   41.458332  2.041667            0.0             5.0
# 1         70.0   40.757140  2.314286            0.0            12.0
# 2         71.0   41.957745  2.070423            0.0            18.0
# 3         60.0   43.700000  1.700000            0.0            12.0
# 4         82.0   42.500000  1.817073            0.0             8.0
#
#    ejections  doubleDouble  tripleDouble  minutes  rebounds  fouls  \
# ...

# %%
dfLimpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8162 entries, 0 to 8161
# Data columns (total 55 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   year                              8162 non-null   int64
#  1   name                              8162 non-null   object
#  2   playerId                          8162 non-null   int64
#  3   playerSlug                        8162 non-null   object
#  4   positionId                        8156 non-null   object
#  5   teamId                            8162 non-null   object
#  6   status                            8162 non-null   object
#  7   gamesPlayed                       8162 non-null   float64
#  8   avgMinutes                        8162 non-null   float64
#  9   avgFouls                          8162 non-null   float64
#  10  flagrantFouls                     8162 non-null   float64
# ...

# %% [markdown]
# # Variáveis categóricas

# %%
col_cat = [
    'year',
    'name',
    'playerId',
    'playerSlug',
    'positionId',
    'teamId',
    'status',
    'position',
    'birthdate',
    'college',
    'draftinfo',
    'birthplace',
    'team',
    'experience',
    'rankingSalary',
    'weight',
    'height'
]

# %%
dfLimpo[col_cat].head()
# Out:
#    year           name  playerId     playerSlug positionId teamId    status  \
# 0  1999  Allen Iverson       366  allen-iverson         SG    PHI  inactive
# 1  2000  Allen Iverson       366  allen-iverson         SG    PHI  inactive
# 2  2001  Allen Iverson       366  allen-iverson         SG    PHI  inactive
# 3  2002  Allen Iverson       366  allen-iverson         SG    PHI  inactive
# 4  2003  Allen Iverson       366  allen-iverson         SG    PHI  inactive
#
#          position birthdate     college               draftinfo   birthplace  \
# 0  Shooting Guard  6/7/1975  Georgetown  1996: Rd 1, Pk 1 (PHI)  Hampton, VA
# 1  Shooting Guard  6/7/1975  Georgetown  1996: Rd 1, Pk 1 (PHI)  Hampton, VA
# 2  Shooting Guard  6/7/1975  Georgetown  1996: Rd 1, Pk 1 (PHI)  Hampton, VA
# 3  Shooting Guard  6/7/1975  Georgetown  1996: Rd 1, Pk 1 (PHI)  Hampton, VA
# 4  Shooting Guard  6/7/1975  Georgetown  1996: Rd 1, Pk 1 (PHI)  Hampton, VA
#
# ...

# %% [markdown]
# name playerId playerSlug
#
# Mesma coisa, vai ficar name

# %%
dfLimpo[col_cat].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8162 entries, 0 to 8161
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           8162 non-null   int64
#  1   name           8162 non-null   object
#  2   playerId       8162 non-null   int64
#  3   playerSlug     8162 non-null   object
#  4   positionId     8156 non-null   object
#  5   teamId         8162 non-null   object
#  6   status         8162 non-null   object
#  7   position       8162 non-null   object
#  8   birthdate      8162 non-null   object
#  9   college        6750 non-null   object
#  10  draftinfo      6977 non-null   object
#  11  birthplace     7947 non-null   object
#  12  team           2304 non-null   object
#  13  experience     2304 non-null   object
#  14  rankingSalary  8162 non-null   int64
#  15  weight         2304 non-null   object
#  16  height         2304 non-null   object
# dtypes: int64(3), object(14)
# ...

# %% [markdown]
# college	draftinfo	birthplace	team	experience	weight	height
#
# Faltam muitos dados serão tirados

# %%
col_cat = [
    'year',
    'name',
    'positionId',
    'teamId',
    'status',
    'position',
    'birthdate',
    'rankingSalary'
]

# %%
dfLimpo[col_cat].head()
# Out:
#    year           name positionId teamId    status        position birthdate  \
# 0  1999  Allen Iverson         SG    PHI  inactive  Shooting Guard  6/7/1975
# 1  2000  Allen Iverson         SG    PHI  inactive  Shooting Guard  6/7/1975
# 2  2001  Allen Iverson         SG    PHI  inactive  Shooting Guard  6/7/1975
# 3  2002  Allen Iverson         SG    PHI  inactive  Shooting Guard  6/7/1975
# 4  2003  Allen Iverson         SG    PHI  inactive  Shooting Guard  6/7/1975
#
#    rankingSalary
# 0             15
# 1             27
# 2             17
# 3             14
# 4             11

# %%
dfLimpo['status'].value_counts()
# O salario era quando estavam na ativa. Não será preciso nesse caso
# Out:
# inactive    5858
# active      2304
# Name: status, dtype: int64

# %%
dfLimpo[['positionId', 'position']].sample(20)
#  Representam a mesma coisa ficarei com positionId por ser sigla
# Out:
#      positionId        position
# 6522         SG  Shooting Guard
# 519          SG  Shooting Guard
# 6068          F         Forward
# 3973         PF   Power Forward
# 35            C          Center
# 1388         SF   Small Forward
# 75            C          Center
# 4779          G           Guard
# 2900          F         Forward
# 4518          F         Forward
# 7377         SF   Small Forward
# 881          SG  Shooting Guard
# 1664          C          Center
# 6370         PG     Point Guard
# 563          PG     Point Guard
# 5045          F         Forward
# 4199          F         Forward
# 5241          F         Forward
# 1896          C          Center
# 6439          F         Forward

# %%
dfLimpo['teamId'].value_counts()
# Out:
# CLE     292
# BOS     287
# SA      286
# SAC     285
# LAC     284
# UTAH    283
# POR     283
# WSH     280
# DAL     279
# NY      279
# TOR     277
# PHI     276
# DEN     274
# DET     271
# MIA     269
# MEM     268
# GS      267
# LAL     266
# MIL     265
# IND     265
# HOU     264
# CHI     263
# ATL     257
# PHX     254
# ORL     252
# MIN     249
# NO      248
# CHA     248
# OKC     204
# NJ      141
# BKN     140
# SEA      90
# VAN      16
# Name: teamId, dtype: int64

# %%
col_cat = [
    'year',
    'name',
    'positionId',
    'teamId',
    'birthdate',
    'rankingSalary'
]

# %%
dfLimpo[col_cat].head()
# Out:
#    year           name positionId teamId birthdate  rankingSalary
# 0  1999  Allen Iverson         SG    PHI  6/7/1975             15
# 1  2000  Allen Iverson         SG    PHI  6/7/1975             27
# 2  2001  Allen Iverson         SG    PHI  6/7/1975             17
# 3  2002  Allen Iverson         SG    PHI  6/7/1975             14
# 4  2003  Allen Iverson         SG    PHI  6/7/1975             11

# %%
col_cat = [
    'year',
    'name',
    'positionId',
    'teamId'
]

# %%
dfLimpo[col_cat].head()
# Out:
#    year           name positionId teamId
# 0  1999  Allen Iverson         SG    PHI
# 1  2000  Allen Iverson         SG    PHI
# 2  2001  Allen Iverson         SG    PHI
# 3  2002  Allen Iverson         SG    PHI
# 4  2003  Allen Iverson         SG    PHI

# %%
col_cat = [
    'positionId',
    'teamId'
]

# %%
dfLimpo[col_cat].head()
# Out:
#   positionId teamId
# 0         SG    PHI
# 1         SG    PHI
# 2         SG    PHI
# 3         SG    PHI
# 4         SG    PHI

# %% [markdown]
# # variáveis Numéricas

# %%
col_num = [    
        'gamesPlayed',
        'avgMinutes',
        'avgFouls',
        'flagrantFouls',
        'technicalFouls',
        'ejections',
        'doubleDouble',
        'tripleDouble',
        'minutes',
        'rebounds',
        'fouls',
        'avgRebounds',
        'avgPoints',
        'avgFieldGoalsMade',
        'avgFieldGoalsAttempted',
        'fieldGoalPct',
        'avgThreePointFieldGoalsMade',
        'avgThreePointFieldGoalsAttempted',
        'threePointFieldGoalPct',
        'avgFreeThrowsMade',
        'avgFreeThrowsAttempted',
        'freeThrowPct',
        'avgAssists',
        'avgTurnovers',
        'points',
        'fieldGoalsMade',
        'fieldGoalsAttempted',
        'threePointFieldGoalsMade',
        'threePointFieldGoalsAttempted',
        'freeThrowsMade',
        'freeThrowsAttempted',
        'assists',
        'turnovers',
        'avgSteals',
        'avgBlocks',
        'steals',
        'blocks',
        'salary']

# %%
dfLimpo[col_num].head()
# Out:
#    gamesPlayed  avgMinutes  avgFouls  flagrantFouls  technicalFouls  \
# 0         48.0   41.458332  2.041667            0.0             5.0
# 1         70.0   40.757140  2.314286            0.0            12.0
# 2         71.0   41.957745  2.070423            0.0            18.0
# 3         60.0   43.700000  1.700000            0.0            12.0
# 4         82.0   42.500000  1.817073            0.0             8.0
#
#    ejections  doubleDouble  tripleDouble  minutes  rebounds  fouls  \
# 0        0.0           4.0           0.0   1990.0     236.0   98.0
# 1        0.0           1.0           0.0   2853.0     267.0  162.0
# 2        0.0           4.0           0.0   2979.0     273.0  147.0
# 3        1.0           4.0           1.0   2622.0     269.0  102.0
# 4        0.0           6.0           0.0   3485.0     344.0  149.0
#
#    avgRebounds  avgPoints  avgFieldGoalsMade  avgFieldGoalsAttempted  \
# 0     4.916666  26.750000           9.062500               22.000000
# ...

# %%
dfLimpo[col_num].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8162 entries, 0 to 8161
# Data columns (total 38 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   gamesPlayed                       8162 non-null   float64
#  1   avgMinutes                        8162 non-null   float64
#  2   avgFouls                          8162 non-null   float64
#  3   flagrantFouls                     8162 non-null   float64
#  4   technicalFouls                    8162 non-null   float64
#  5   ejections                         8162 non-null   float64
#  6   doubleDouble                      8162 non-null   float64
#  7   tripleDouble                      8162 non-null   float64
#  8   minutes                           8162 non-null   float64
#  9   rebounds                          8162 non-null   float64
#  10  fouls                             8162 non-null   float64
# ...

# %%
dfNumerico = dfLimpo[col_num].copy()

# %%
corr_matrix = dfNumerico.corr()

# %%
corr_matrix['salary']
# Out:
# gamesPlayed                         0.218112
# avgMinutes                          0.546872
# avgFouls                            0.299529
# flagrantFouls                       0.125905
# technicalFouls                      0.350151
# ejections                           0.150203
# doubleDouble                        0.451649
# tripleDouble                        0.282489
# minutes                             0.445531
# rebounds                            0.432619
# fouls                               0.283894
# avgRebounds                         0.470315
# avgPoints                           0.663278
# avgFieldGoalsMade                   0.654786
# avgFieldGoalsAttempted              0.623984
# fieldGoalPct                        0.173089
# avgThreePointFieldGoalsMade         0.408205
# avgThreePointFieldGoalsAttempted    0.414172
# threePointFieldGoalPct              0.134676
# avgFreeThrowsMade                   0.578352
# avgFreeThrowsAttempted              0.569542
# ...

# %%
corr_matrix['salary'].sort_values(ascending=False)[:13]
# Out:
# salary                    1.000000
# avgPoints                 0.663278
# avgFieldGoalsMade         0.654786
# avgFieldGoalsAttempted    0.623984
# points                    0.583561
# avgFreeThrowsMade         0.578352
# fieldGoalsMade            0.574301
# avgFreeThrowsAttempted    0.569542
# avgTurnovers              0.547378
# fieldGoalsAttempted       0.546904
# avgMinutes                0.546872
# freeThrowsMade            0.529688
# freeThrowsAttempted       0.521237
# Name: salary, dtype: float64

# %%
col_num = [
    'salary',
    'avgPoints',
    'avgFieldGoalsMade',
    'avgFieldGoalsAttempted',
    'points',
    'avgFreeThrowsMade',
    'fieldGoalsMade',
    'avgFreeThrowsAttempted',
    'avgTurnovers',
    'fieldGoalsAttempted',
    'avgMinutes',
    'freeThrowsMade',
    'freeThrowsAttempted'
]

# %%
dfNumerico[col_num].head()
# Out:
#        salary  avgPoints  avgFieldGoalsMade  avgFieldGoalsAttempted  points  \
# 0  9000000.00      26.75               9.06                   22.00 1284.00
# 1 10125000.00      28.41              10.41                   24.76 1989.00
# 2 11250000.00      31.08              10.73                   25.54 2207.00
# 3 12375000.00      31.38              11.08                   27.82 1883.00
# 4 13500000.00      27.59               9.80                   23.66 2262.00
#
#    avgFreeThrowsMade  fieldGoalsMade  avgFreeThrowsAttempted  avgTurnovers  \
# 0               7.42          435.00                    9.88          3.48
# 1               6.31          729.00                    8.86          3.29
# 2               8.24          762.00                   10.13          3.34
# 3               7.92          665.00                    9.75          3.95
# 4               6.95          804.00                    8.98          3.49
#
# ...

# %%
dfNumerico = dfLimpo[col_num].copy()

# %%
dfNumerico['salary'].hist(bins = 100);

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
dfNumerico.head()
# Out:
#        salary  avgPoints  avgFieldGoalsMade  avgFieldGoalsAttempted  points  \
# 0  9000000.00      26.75               9.06                   22.00 1284.00
# 1 10125000.00      28.41              10.41                   24.76 1989.00
# 2 11250000.00      31.08              10.73                   25.54 2207.00
# 3 12375000.00      31.38              11.08                   27.82 1883.00
# 4 13500000.00      27.59               9.80                   23.66 2262.00
#
#    avgFreeThrowsMade  fieldGoalsMade  avgFreeThrowsAttempted  avgTurnovers  \
# 0               7.42          435.00                    9.88          3.48
# 1               6.31          729.00                    8.86          3.29
# 2               8.24          762.00                   10.13          3.34
# 3               7.92          665.00                    9.75          3.95
# 4               6.95          804.00                    8.98          3.49
#
# ...

# %%
g = dfNumerico.hist(bins = 50, figsize = (20, 15))

# %%
import matplotlib.pyplot as plt

# %%
columns = list(corr_matrix.columns)

cm = plt.get_cmap('jet') # viridis,inferno,plasma

fig, ax = plt.subplots(figsize = (10, 10))
ax.matshow(corr_matrix,cmap=cm)

# cbar = plt.colorbar()
# cbar.ax.set_ylabel('r')

# ax = plt.gca() # get the current axes
ax.set_xticks(range(len(columns)))
ax.set_yticks(range(len(columns)))
ax.set_xticklabels(columns)
ax.set_yticklabels(columns)

# Rotate the tick labels and set their alignment
r = plt.setp(ax.get_xticklabels(), rotation=45, ha="left", rotation_mode="anchor")
