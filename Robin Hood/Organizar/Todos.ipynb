# %%
#!pip install selenium

# %%
from selenium import webdriver

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
from selenium.webdriver.firefox.options import Options
import time
import pandas as pd
import csv

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
tabela = pd.DataFrame(columns = ['Jogo', 'Vitoria', 'Empate', 'Derrota', 'Local'])

# %%
options = Options()
options.headless = True
options.add_argument('window-size=1920x1080')

# %% [markdown]
# ## Bet365

# %%
driver = webdriver.Firefox()
driver.get("https://www.bet365.com/#/AC/B1/C1/D1002/E71022033/G40/")
#time.sleep(4)

# %%
driver = webdriver.Firefox()
driver.get("https://www.bet365.com/#/AC/B1/C1/D1002/E71022033/G40/", options=options)
#time.sleep(4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [19], in <cell line: 2>()
#       1 driver = webdriver.Firefox()
# ----> 2 driver.get("https://www.bet365.com/#/AC/B1/C1/D1002/E71022033/G40/", options=options)
#
# TypeError: get() got an unexpected keyword argument 'options'

# %%
div_mae = driver.find_element("xpath", '/html/body/div[1]/div/div[4]/div[2]/div/div/div[2]/div[1]/div/div/div[2]/div/div/div[2]/div[2]/div')
html_conteudo = div_mae.get_attribute('outerHTML')
soup = BeautifulSoup(html_conteudo, 'html.parser')
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 div_mae = driver.find_element("xpath", '/html/body/div[1]/div/div[4]/div[2]/div/div/div[2]/div[1]/div/div/div[2]/div/div/div[2]/div[2]/div')
#       2 html_conteudo = div_mae.get_attribute('outerHTML')
#       3 soup = BeautifulSoup(html_conteudo, 'html.parser')
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:855, in WebDriver.find_element(self, by, value)
#     852     by = By.CSS_SELECTOR
#     853     value = '[name="%s"]' % value
# --> 855 return self.execute(Command.FIND_ELEMENT, {
#     856     'using': by,
#     857     'value': value})['value']
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:428, in WebDriver.execute(self, driver_command, params)
# ...

# %%
times = soup.find_all('div', class_='rcl-ParticipantFixtureDetailsTeam_TeamName')
valores = soup.find_all('span', class_='sgl-ParticipantOddsOnly80_Odds')

# %%
for i in range(len(times)):
    if i % 2 == 0:
        listaJogos = times[i].text + " x " + times[i+1].text
        listaVitoria = (valores[int(i/2)].text)
        listaEmpates = (valores[int(i/2 + len(times)/2)].text)
        listaDerrota = (valores[int(i/2 + 2*len(times)/2)].text)
        tabela = tabela.append({'Jogo' : listaJogos,
                                'Vitoria' : listaVitoria,
                                'Empate' : listaEmpates,
                                'Derrota' : listaDerrota,
                                'Local' : 'Bet365'}, 
                        ignore_index=True)

# %% [markdown]
# ## Betway

# %%
driver = webdriver.Firefox()
driver.get("https://betway.com/pt/sports/grp/soccer/brazil/brasileiro-serie-a")
#time.sleep(4)

# %%
div_mae = driver.find_element("xpath", '/html/body/div[1]/div/div[3]/div/div[1]/div/div[2]/div[4]/div/div[3]')
html_conteudo = div_mae.get_attribute('outerHTML')
soup = BeautifulSoup(html_conteudo, 'html.parser')

# %%
times = soup.find_all('span', class_='teamNameFirstPart')
valores = soup.find_all('div', class_='odds')

# %%
for i in range(len(times)):
    if i % 2 == 0:
        listaJogos = times[i].text + " x " + times[i+1].text
        listaVitoria = (valores[int(3*i/2)].text)
        listaEmpates = (valores[int(3*i/2+1)].text)
        listaDerrota = (valores[int(3*i/2+2)].text)
        tabela = tabela.append({'Jogo' : listaJogos,
                                'Vitoria' : listaVitoria,
                                'Empate' : listaEmpates,
                                'Derrota' : listaDerrota,
                                'Local' : 'betway'}, 
                        ignore_index=True)
# Out:
# C:\Users\Eduardo\AppData\Local\Temp\ipykernel_4684\3625743891.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tabela = tabela.append({'Jogo' : listaJogos,
# C:\Users\Eduardo\AppData\Local\Temp\ipykernel_4684\3625743891.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tabela = tabela.append({'Jogo' : listaJogos,
# C:\Users\Eduardo\AppData\Local\Temp\ipykernel_4684\3625743891.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tabela = tabela.append({'Jogo' : listaJogos,
# C:\Users\Eduardo\AppData\Local\Temp\ipykernel_4684\3625743891.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %% [markdown]
# ## Betfair

# %%
driver = webdriver.Firefox()
driver.get("https://www.betfair.com/sport/football/brasil-s%C3%A9rie-a/13")
#time.sleep(4)

# %%
div_mae = driver.find_element("xpath", '//*[@id="mod-multipickavb-1002"]')
html_conteudo = div_mae.get_attribute('outerHTML')
soup = BeautifulSoup(html_conteudo, 'html.parser')
teste = soup.prettify()

# %%
times = soup.find_all('span', class_='team-name')
valores = soup.find_all('span', class_='ui-display-decimal-price')

# %%
for i in range(len(times)):
    if i % 2 == 0:
        listaJogos = (times[i].text).replace('\n', '') + " x " + (times[i+1].text).replace('\n', '')
        listaVitoria = (valores[int(5*i/2+2)].text).replace('\n', '')
        listaEmpates = (valores[int(5*i/2+3)].text).replace('\n', '')
        listaDerrota = (valores[int(5*i/2+4)].text).replace('\n', '')
        tabela = tabela.append({'Jogo' : listaJogos,
                                'Vitoria' : listaVitoria,
                                'Empate' : listaEmpates,
                                'Derrota' : listaDerrota,
                                'Local' : 'Betfair'}, 
                        ignore_index=True)

# %% [markdown]
# ## Pinnacle

# %%
driver = webdriver.Firefox()
driver.get("https://www.pinnacle.com/pt/soccer/brazil-serie-a/matchups#period:0")

# %%
div_mae = driver.find_element("xpath", '/html/body/div[2]/div/div[2]/main/div')
html_conteudo = div_mae.get_attribute('outerHTML')
soup = BeautifulSoup(html_conteudo, 'html.parser')

# %%
times = soup.find_all('span', class_='event-row-participant')
valores = soup.find_all('span', class_='style_price__15SlF')

# %%
for i in range(len(times)):
    if i % 2 == 0:
        listaJogos = times[i].text + " x " + times[i+1].text
        listaVitoria = (valores[int(7*i/2)].text)
        listaEmpates = (valores[int(7*i/2+1)].text)
        listaDerrota = (valores[int(7*i/2+2)].text)
        tabela = tabela.append({'Jogo' : listaJogos,
                                'Vitoria' : listaVitoria,
                                'Empate' : listaEmpates,
                                'Derrota' : listaDerrota,
                                'Local' : 'Pinnacle'}, 
                        ignore_index=True)
# Out:
# C:\Users\Eduardo\AppData\Local\Temp\ipykernel_15096\1477934715.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tabela = tabela.append({'Jogo' : listaJogos,
# C:\Users\Eduardo\AppData\Local\Temp\ipykernel_15096\1477934715.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tabela = tabela.append({'Jogo' : listaJogos,
# C:\Users\Eduardo\AppData\Local\Temp\ipykernel_15096\1477934715.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tabela = tabela.append({'Jogo' : listaJogos,
# C:\Users\Eduardo\AppData\Local\Temp\ipykernel_15096\1477934715.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %% [markdown]
# ## Resultado

# %%
#Atlético-GO
tabela["Jogo"] = tabela["Jogo"].replace ("Atlético Goianiense", "Atlético-GO", regex=True)
tabela["Jogo"] = tabela["Jogo"].replace ("AC Goianiense GO", "Atlético-GO", regex=True)
#Atlético-MG
tabela["Jogo"] = tabela["Jogo"].replace ("Atletico Mineiro MG", "Atlético-MG", regex=True)
tabela["Jogo"] = tabela["Jogo"].replace ("Atletico Mineiro", "Atlético-MG", regex=True)
tabela["Jogo"] = tabela["Jogo"].replace ("Atlético Mineiro", "Atlético-MG", regex=True)
#Athletico-PR
tabela["Jogo"] = tabela["Jogo"].replace ("Athletico PR", "Athletico-PR", regex=True)
tabela["Jogo"] = tabela["Jogo"].replace ("Athletico Paranaense", "Athletico-PR", regex=True)
tabela["Jogo"] = tabela["Jogo"].replace ("CA Paranaense PR", "Athletico-PR", regex=True)
#América-MG
tabela["Jogo"] = tabela["Jogo"].replace ("América Mineiro", "América-MG", regex=True)
tabela["Jogo"] = tabela["Jogo"].replace ("America FC MG", "América-MG", regex=True)
#Botafogo  
tabela["Jogo"] = tabela["Jogo"].replace ("Botafogo FR RJ", "Botafogo", regex=True)
#Bragantino 
tabela["Jogo"] = tabela["Jogo"].replace ("Red Bull Bragantino SP", "Bragantino", regex=True)
#Ceara  
tabela["Jogo"] = tabela["Jogo"].replace ("Ceará SC CE", "Ceará", regex=True)
#Corinthians
tabela["Jogo"] = tabela["Jogo"].replace ("SC Corinthians SP", "Corinthians", regex=True)
#Cuiabá
tabela["Jogo"] = tabela["Jogo"].replace ("Cuiabá EC", "Cuiabá", regex=True)
tabela["Jogo"] = tabela["Jogo"].replace ("Cuiaba Esporte Clube MT", "Cuiabá", regex=True)
#Flamengo  
tabela["Jogo"] = tabela["Jogo"].replace ("CR Flamengo RJ", "Flamengo", regex=True)
#Fluminense
tabela["Jogo"] = tabela["Jogo"].replace ("Fluminense FC RJ", "Fluminense", regex=True)
#Fortaleza
tabela["Jogo"] = tabela["Jogo"].replace ("Fortaleza EC CE", "Fortaleza", regex=True)
#Goias EC GO
tabela["Jogo"] = tabela["Jogo"].replace ("Goias EC GO", "Goiás", regex=True)
#Internacional
tabela["Jogo"] = tabela["Jogo"].replace ("SC Internacional RS", "Internacional", regex=True)
#Juventude 
tabela["Jogo"] = tabela["Jogo"].replace ("EC Juventude RS", "Juventude", regex=True)
#Palmeiras  
tabela["Jogo"] = tabela["Jogo"].replace ("Se Palmeiras Sp", "Palmeiras", regex=True)
#Santos 
tabela["Jogo"] = tabela["Jogo"].replace ("Santos FC SP", "Santos", regex=True)
#São Paulo
tabela["Jogo"] = tabela["Jogo"].replace ("Sao Paulo FC SP", "São Paulo", regex=True)

# %%
tabela.sort_values(by=['Jogo'])
# Out:
#                                        Jogo Vitoria Empate Derrota     Local
# 23                Avaí FC SC x Athletico-PR   2.820  3.170   2.720  Pinnacle
# 13                      Avaí x Athletico-PR     2.8    3.0     2.6   Betfair
# 4                       Avaí x Athletico-PR    2,75   3,10    2,60    betway
# 22           Botafogo Fr Rj x América FC MG   2.190  3.180   3.740  Pinnacle
# 5                     Botafogo x América-MG    2,15   3,20    3,40    betway
# 14                    Botafogo x América-MG    2.15   3.25     3.5   Betfair
# 19                           Ceará x Santos   2.130  3.320   3.800  Pinnacle
# 9                            Ceará x Santos     2.0   3.25    3.75   Betfair
# 0                            Ceará x Santos    2,10   3,20    3,50    betway
# 24             Coritiba FC PR x Atlético-GO   2.210  3.240   3.590  Pinnacle
# 6                   Coritiba x  Atlético-GO    2,20   3,20    3,30    betway
# ...

# %%
desco = tabela.groupby('Jogo').max()

# %%
tabela = tabela.replace (",", ".", regex=True)

# %%
tabela['valor'] = 1 - (1/tabela['Vitoria'].astype(float))- (1/tabela['Empate'].astype(float))- (1/tabela['Derrota'].astype(float))

# %%
desco['valor'] = 1 - (1/desco['Vitoria'].astype(float))- (1/desco['Empate'].astype(float))- (1/desco['Derrota'].astype(float))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 desco['valor'] = 1 - (1/desco['Vitoria'].astype(float))- (1/desco['Empate'].astype(float))- (1/desco['Derrota'].astype(float))
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# ...

# %%
s = '10,5674'

s = s.replace (",", ".", regex=True)
f = float(s)

print(type(f))

# %%
tabela
# Out:
#                                        Jogo Vitoria Empate Derrota     Local  \
# 0                            Ceará x Santos    2.10   3.20    3.50    betway
# 1                    Internacional x Cuiabá    1.57   3.75    6.00    betway
# 2                    Fluminense x Fortaleza    1.83   3.30    4.50    betway
# 3                     Palmeiras x Juventude    1.18   6.50   15.00    betway
# 4                       Avaí x Athletico-PR    2.75   3.10    2.60    betway
# 5                     Botafogo x América-MG    2.15   3.20    3.40    betway
# 6                   Coritiba x  Atlético-GO    2.20   3.20    3.30    betway
# 7                   São Paulo x Corinthians    2.15   3.10    3.50    betway
# 8                          Goiás x Flamengo    5.75   3.80    1.57    betway
# 9                            Ceará x Santos     2.0   3.25    3.75   Betfair
# 10                   Internacional x Cuiabá     1.5   3.75     7.0   Betfair
# ...
