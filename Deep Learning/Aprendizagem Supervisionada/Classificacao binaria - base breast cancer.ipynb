# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score

import keras
from keras.models import Sequential
from keras.layers import Dense

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# Out:
# Using TensorFlow backend.
# In /home/eduardo/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.frameon rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
# In /home/eduardo/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The verbose.level rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
# In /home/eduardo/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The verbose.fileo rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.

# %%
entradas = pd.read_csv("../data/entradas_breast.csv")
saidas = pd.read_csv("../data/saidas_breast.csv")

# %%
entradas.head()
# Out:
#     radius_mean   texture_mean   perimeter_mean   area_mean   smoothness_mean  \
# 0         17.99          10.38           122.80      1001.0           0.11840
# 1         20.57          17.77           132.90      1326.0           0.08474
# 2         19.69          21.25           130.00      1203.0           0.10960
# 3         11.42          20.38            77.58       386.1           0.14250
# 4         20.29          14.34           135.10      1297.0           0.10030
#
#     compactness_mean   concavity_mean  concave_points_mean   symmetry_mean  \
# 0            0.27760           0.3001              0.14710          0.2419
# 1            0.07864           0.0869              0.07017          0.1812
# 2            0.15990           0.1974              0.12790          0.2069
# 3            0.28390           0.2414              0.10520          0.2597
# 4            0.13280         198.0000              0.10430          0.1809
#
# ...

# %%
entradas_train, entradas_test, saidas_train, saidas_test = train_test_split(entradas, saidas, test_size=0.25)

# %%
image = mpimg.imread("../img/rede neural densa.png")
plt.imshow(image)
plt.show()

# %% [markdown]
# # Rede Neural com uma camada oculta

# %%
classificador = Sequential()
classificador.add(Dense(units=16, activation="relu", kernel_initializer="random_uniform", input_dim = 30))

# %%
classificador.add(Dense(units = 1, activation="sigmoid"))

# %%
image = mpimg.imread("../img/rede neural exemplo.png")
plt.imshow(image)
plt.show()

# %%
classificador.compile(optimizer="adam", loss="binary_crossentropy", metrics=["binary_accuracy"])

# %%
classificador.fit(entradas_train, saidas_train, batch_size=10, epochs=100)
# Out:
# Epoch 1/100
# 426/426 [==============================] - 1s 3ms/step - loss: 7.3923 - binary_accuracy: 0.5423
# Epoch 2/100
# 426/426 [==============================] - 0s 292us/step - loss: 1.2293 - binary_accuracy: 0.7089
# Epoch 3/100
# 426/426 [==============================] - 0s 263us/step - loss: 0.4706 - binary_accuracy: 0.8192
# Epoch 4/100
# 426/426 [==============================] - 0s 307us/step - loss: 0.3437 - binary_accuracy: 0.8732
# Epoch 5/100
# 426/426 [==============================] - 0s 314us/step - loss: 0.3998 - binary_accuracy: 0.8451
# Epoch 6/100
# 426/426 [==============================] - 0s 308us/step - loss: 0.5016 - binary_accuracy: 0.8380
# Epoch 7/100
# 426/426 [==============================] - 0s 314us/step - loss: 0.6274 - binary_accuracy: 0.8122
# Epoch 8/100
# 426/426 [==============================] - 0s 298us/step - loss: 0.5025 - binary_accuracy: 0.8592
# Epoch 9/100
# ...

# %%
previsoes = classificador.predict(entradas_test)
previsoes = (previsoes > 0.5)
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.

# %%
previsao = accuracy_score(saidas_test, previsoes)
previsao
# Out:
# 0.9020979020979021

# %%
matriz_confusao = confusion_matrix(saidas_test, previsoes)
matriz_confusao
# Out:
# array([[47, 10],
#        [ 4, 82]])

# %%
resultado = classificador.evaluate(entradas_test, saidas_test)
resultado
# Out:
# 143/143 [==============================] - 0s 2ms/step
# [0.5105350853263081, 0.9020978808403015]

# %% [markdown]
# # Rede Neural com duas camadas ocultas

# %%
classificador = Sequential()
classificador.add(Dense(units=16, activation="relu", kernel_initializer="random_uniform", input_dim = 30))

# %%
classificador.add(Dense(units=16, activation="relu", kernel_initializer="random_uniform"))

# %%
classificador.add(Dense(units = 1, activation="sigmoid"))

# %%
image = mpimg.imread("../img/rede neural densa dupla.png")
plt.imshow(image)
plt.show()

# %%
optimizador = keras.optimizers.Adam(lr= 0.001, decay= 0.0001, clipvalue= 0.5)

# %%
classificador.compile(optimizer=optimizador, loss="binary_crossentropy", metrics=["binary_accuracy"])

# %%
classificador.fit(entradas_train, saidas_train, batch_size=10, epochs=100)
# Out:
# Epoch 1/100
# 426/426 [==============================] - 4s 9ms/step - loss: 0.6823 - binary_accuracy: 0.6549
# Epoch 2/100
# 426/426 [==============================] - 0s 228us/step - loss: 0.4496 - binary_accuracy: 0.8122
# Epoch 3/100
# 426/426 [==============================] - 0s 279us/step - loss: 0.4195 - binary_accuracy: 0.7911
# Epoch 4/100
# 426/426 [==============================] - 0s 265us/step - loss: 0.3801 - binary_accuracy: 0.8498
# Epoch 5/100
# 426/426 [==============================] - 0s 235us/step - loss: 0.3658 - binary_accuracy: 0.8756
# Epoch 6/100
# 426/426 [==============================] - 0s 208us/step - loss: 0.3353 - binary_accuracy: 0.8850
# Epoch 7/100
# 426/426 [==============================] - 0s 189us/step - loss: 0.3717 - binary_accuracy: 0.8662
# Epoch 8/100
# 426/426 [==============================] - 0s 162us/step - loss: 0.3171 - binary_accuracy: 0.8897
# Epoch 9/100
# ...

# %% [markdown]
# # Calculando os pesos da Rede Neural

# %%
pesos0 = classificador.layers[0].get_weights()
pesos0
# Out:
# [array([[-9.16188359e-02,  4.68987860e-02, -1.39565617e-01,
#           5.71425930e-02,  4.82690812e-05, -1.20942295e-01,
#           6.70352057e-02,  1.46622835e-02, -1.96118042e-01,
#           1.02225088e-01, -6.21616468e-02, -2.65593436e-02,
#           2.14645453e-02,  1.66644186e-01, -1.10967919e-01,
#          -7.88850039e-02],
#         [-7.77765885e-02,  4.85640876e-02, -3.38713586e-01,
#           1.20503783e-01, -5.73098771e-02, -2.36543864e-01,
#           1.05866559e-01,  4.22922941e-03, -2.12035432e-01,
#           1.83964372e-01, -1.44855902e-01,  1.02631703e-01,
#           8.74780044e-02,  2.25098491e-01, -1.18640848e-01,
#          -4.72208709e-02],
#         [-9.86076295e-02, -2.37550307e-02, -3.59435603e-02,
#          -1.30290121e-01,  4.61697988e-02, -1.23999856e-01,
#           1.16608374e-01, -1.56822931e-02, -1.34205624e-01,
#          -3.05320770e-02, -1.10838026e-01,  3.81785352e-03,
#           4.77016009e-02,  1.68771327e-01, -1.25474051e-01,
# ...

# %%
pesos1 = classificador.layers[1].get_weights()
pesos1
# Out:
# [array([[ 1.52523100e-01, -5.32919206e-02,  6.10327534e-02,
#          -3.69658247e-02, -4.37333286e-02, -2.77788043e-02,
#          -6.55262768e-02, -2.34784763e-02,  4.20422256e-02,
#           3.24322432e-02, -5.20126373e-02,  4.77335714e-02,
#          -6.48467541e-02, -3.84551026e-02, -4.88508195e-02,
#          -2.14328617e-03],
#         [-9.06949863e-02, -1.58915773e-01, -1.23621054e-01,
#           1.21732198e-01, -8.46757591e-02, -4.23041098e-02,
#           4.64185514e-02, -2.10776448e-01,  3.85816135e-02,
#           2.41438183e-03, -3.32185440e-02,  2.98608877e-02,
#          -1.19025409e-01, -2.13759784e-02,  9.43481736e-03,
#           1.23445794e-03],
#         [ 8.09802711e-02,  5.01746349e-02,  1.10105596e-01,
#          -5.51655777e-02, -2.68278481e-03, -4.95834723e-02,
#          -5.02965450e-02,  1.51293725e-01, -1.66159682e-02,
#           2.58984277e-03, -1.16845509e-02,  5.29931385e-05,
#           2.61743627e-02, -6.72267377e-02, -1.84663106e-02,
# ...

# %%
pesos2 = classificador.layers[2].get_weights()
pesos2
# Out:
# [array([[-0.26566818],
#         [ 0.15899177],
#         [ 0.4452915 ],
#         [ 0.3316664 ],
#         [ 0.12916411],
#         [-0.07427002],
#         [-0.2640209 ],
#         [ 0.24274285],
#         [-0.28804037],
#         [-0.5434684 ],
#         [-0.20187692],
#         [-0.43747666],
#         [-0.59310645],
#         [-0.46285206],
#         [-0.32371512],
#         [-0.45207632]], dtype=float32), array([0.14460728], dtype=float32)]
