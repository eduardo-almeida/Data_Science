# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import keras
from keras.models import Sequential
from keras.layers import Dense

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# Out:
# In /home/eduardo/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.frameon rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
# In /home/eduardo/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The verbose.level rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
# In /home/eduardo/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The verbose.fileo rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.

# %%
entradas = pd.read_csv("../data/entradas_breast.csv")
saidas = pd.read_csv("../data/saidas_breast.csv")

# %%
entradas.head()
# Out:
#     radius_mean   texture_mean   perimeter_mean   area_mean   smoothness_mean  \
# 0         17.99          10.38           122.80      1001.0           0.11840
# 1         20.57          17.77           132.90      1326.0           0.08474
# 2         19.69          21.25           130.00      1203.0           0.10960
# 3         11.42          20.38            77.58       386.1           0.14250
# 4         20.29          14.34           135.10      1297.0           0.10030
#
#     compactness_mean   concavity_mean  concave_points_mean   symmetry_mean  \
# 0            0.27760           0.3001              0.14710          0.2419
# 1            0.07864           0.0869              0.07017          0.1812
# 2            0.15990           0.1974              0.12790          0.2069
# 3            0.28390           0.2414              0.10520          0.2597
# 4            0.13280         198.0000              0.10430          0.1809
#
# ...

# %%
entradas_train, entradas_test, saidas_train, saidas_test = train_test_split(entradas, saidas, test_size=0.25)

# %%
image = mpimg.imread("../img/rede neural densa.png")
plt.imshow(image)
plt.show()

# %%
classificador = Sequential()
classificador.add(Dense(units=16, activation="relu", kernel_initializer="random_uniform", input_dim = 30))

# %%
classificador.add(Dense(units = 1, activation="sigmoid"))

# %%
image = mpimg.imread("../img/rede neural exemplo.png")
plt.imshow(image)
plt.show()

# %%
classificador.compile(optimizer="adam", loss="binary_crossentropy", metrics=["binary_accuracy"])

# %%
classificador.fit(entradas_train, saidas_train, batch_size=10, epochs=100)
# Out:
# Epoch 1/100
# 426/426 [==============================] - 1s 3ms/step - loss: 8.7004 - binary_accuracy: 0.6080
# Epoch 2/100
# 426/426 [==============================] - 0s 183us/step - loss: 0.9920 - binary_accuracy: 0.8005
# Epoch 3/100
# 426/426 [==============================] - 0s 157us/step - loss: 0.6031 - binary_accuracy: 0.8169
# Epoch 4/100
# 426/426 [==============================] - 0s 158us/step - loss: 0.4445 - binary_accuracy: 0.8568
# Epoch 5/100
# 426/426 [==============================] - 0s 150us/step - loss: 0.6461 - binary_accuracy: 0.8122
# Epoch 6/100
# 426/426 [==============================] - 0s 152us/step - loss: 0.6087 - binary_accuracy: 0.8310
# Epoch 7/100
# 426/426 [==============================] - 0s 148us/step - loss: 0.3578 - binary_accuracy: 0.8897
# Epoch 8/100
# 426/426 [==============================] - 0s 157us/step - loss: 0.4952 - binary_accuracy: 0.8427
# Epoch 9/100
# ...
